# %%
import nibabel as nib
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib as mpl
from scipy import stats
from scipy import ndimage
import glob
import csv
import os
import re
import math
import sys
import plotly.plotly as py
from plotly.graph_objs import *
from pylab import *


import sklearn
from sklearn import svm
from sklearn import datasets
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

from sklearn.metrics import roc_curve, auc

# %matplotlib inline

# %%
X_GLCM = []
f_GLCM = open('/Volumes/vph-prism5/Sara/SPIE16/Manuscript/LightLines/LightLines_GLCM_features_4_21.csv')
f_GLCM.readline()  # skip the header
GLCMreader = csv.reader(f_GLCM)
for row in GLCMreader:
    X_GLCM.append(row)
    
y_labels = np.loadtxt('/Volumes/vph-prism5/Sara/SPIE16/Manuscript/LightLines/LightLines_GLCM_labels.csv', delimiter = ',', usecols=(2,), dtype = int)
#filenames
z_names = np.loadtxt('/Volumes/vph-prism5/Sara/SPIE16/Manuscript/LightLines/LightLines_GLCM_labels.csv', delimiter = ',', usecols=(0,), dtype = str)


X_LBP = []
f_LBP = open('/Volumes/vph-prism5/Sara/SPIE16/Manuscript/LightLines/LightLines_LBP_features_r2.csv')
f_LBP.readline()  # skip the header
LBPreader = csv.reader(f_LBP)
for row in LBPreader:
    X_LBP.append(row)
    
merged_features=[]
for i in range(len(X_GLCM)):
    merged_features.append(X_GLCM[i]+X_LBP[i])
    
LBP_header = np.arange(17).tolist()
csvSummaryResultsHeader = ['Contrast_mean', 'Contrast_std', 'Contrast_min', 'Contrast_max', 'Dissimilarity_mean', 'Dissimilarity_std', 'Dissimilarity_min', 'Dissimilarity_max', 'Homogeneity_mean', 'Homogeneity_std', 'Homogeneity_min', 'Homogeneity_max', 'ASM_mean', 'ASM_std', 'ASM_min', 'ASM_max', 'Energy_mean', 'Energy_std', 'Energy_min', 'Energy_max', 'Correlation_mean', 'Correlation_std', 'Correlation_min', 'Correlation_max', 'Entropy_mean', 'Entropy_std', 'Entropy_min', 'Entropy_max'] + LBP_header
    
file = open('/Volumes/vph-prism5/Sara/SPIE16/Manuscript/merged_features.csv', "wb")
writer = csv.writer(file)
writer.writerow(csvSummaryResultsHeader)
writer.writerows(merged_features)
file.close()
    
#print len(merged_features)
#print merged_features[0:2]

X_array_features = np.array(merged_features)
print X_array_features.shape

n_sample = len(X_array_features)

np.random.seed(0)
order = np.random.permutation(n_sample)
X_features = X_array_features[order]
y_labels = y_labels[order].astype(np.float)
z_names = z_names[order]

X_train = X_features[:.7 * n_sample] ## select 70% of the data to train
y_train = y_labels[:.7 * n_sample]
X_test = X_features[.7 * n_sample:]
y_test = y_labels[.7 * n_sample:]
z_test = z_names[.7 * n_sample:]
print z_test
# Out:
# (104, 45)
# ['30_01_m' '09_06_i' '12_02_i' '19_01_m' '40_02_i' '40_03_i' '28_02_i'
#  '10_01_i' '39_01_i' '29_02_i' '31_02_m' '11_03_i' '15_02_i' '33_02_m'
#  '17_03_i' '15_04_i' '26_02_i' '22_02_i' '08_01_i' '37_01_m' '36_01_i'
#  '28_03_m' '35_04_i' '15_01_m' '10_02_i' '34_01_i' '05_03_i' '39_03_i'
#  '27_01_m' '26_01_m' '18_01_m' '17_01_i']

# %%
C=[]
gamma=[]
#for i in range(21): C.append(10.0**(i-5))
#for i in range(17): gamma.append(10**(i-14))

for i in range(6): C.append(10.0**(i-1))
for i in range(5): gamma.append(10**(i-5))
    
print C
print gamma
###-----------------------------------------------------------###
#---------- Set the parameters by cross-validation -----------###
###-----------------------------------------------------------###

'''
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4, 1e-5],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]
'''

tuned_parameters = [{'kernel': ['rbf'], 'gamma': gamma,
                     'C': C},
                    {'kernel': ['linear'], 'C': C}]

#scores = ['precision', 'recall']
scores = ['accuracy', 'f1'] # optimize for accuracy rather than precision or recall, or for F1 if you have a situation with unbalanced classes.

print "RGB:"

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(C=1), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
              % (mean_score, scores.std() * 2, params))
    print()

    print("Detailed classification report (RGB):")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
    print("Confusion matrix")
    print(confusion_matrix(y_test, y_pred))
    print()
# Out:
# [0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0]
# [1e-05, 0.0001, 0.001, 0.01, 0.1]
# RGB:
# # Tuning hyper-parameters for accuracy
# ()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-84fc3e4625a3> in <module>()
#      34     clf = GridSearchCV(SVC(C=1), tuned_parameters, cv=5,
#      35                        scoring='%s' % score)
# ---> 36     clf.fit(X_train, y_train)
#      37
#      38     print("Best parameters set found on development set:")
#
# /Library/Python/2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     730
#     731         """
# --> 732         return self._fit(X, y, ParameterGrid(self.param_grid))
#     733
#     734
#
# /Library/Python/2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     503                                     self.fit_params, return_parameters=True,
#     504                                     error_score=self.error_score)
# --> 505                 for parameters in parameter_iterable
#     506                 for train, test in cv)
#     507
#
# /Library/Python/2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# /Library/Python/2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# /Library/Python/2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# /Library/Python/2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1457             estimator.fit(X_train, **fit_params)
#    1458         else:
# -> 1459             estimator.fit(X_train, y_train, **fit_params)
#    1460
#    1461     except Exception as e:
#
# /Library/Python/2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     176
#     177         seed = rnd.randint(np.iinfo('i').max)
# --> 178         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     179         # see comment on the other call to np.iinfo in this file
#     180
#
# /Library/Python/2.7/site-packages/sklearn/svm/base.pyc in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     234                 cache_size=self.cache_size, coef0=self.coef0,
#     235                 gamma=self._gamma, epsilon=self.epsilon,
# --> 236                 max_iter=self.max_iter, random_seed=random_seed)
#     237
#     238         self._warn_from_fit_status()
#
# KeyboardInterrupt:
